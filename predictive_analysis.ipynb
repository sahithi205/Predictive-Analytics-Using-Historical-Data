# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
data = pd.read_csv("data/sales_data.csv")

data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 data = pd.read_csv("data/sales_data.csv")
#       2
#       3 data.head()
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...

# %%
X = data[['Month']]
y = data['Sales']

# %%
model = LinearRegression()

model.fit(X, y)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X)

# %%
mae = mean_absolute_error(y, predictions)

print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 5.091877591877597

# %%
future_months = pd.DataFrame({
    'Month': [37, 38, 39]
})

future_predictions = model.predict(future_months)

for month, sale in zip(future_months['Month'], future_predictions):
    print(f"Month {month}: {sale:.2f}")
# Out:
# Month 37: 1159.49
# Month 38: 1186.57
# Month 39: 1213.64

# %%
plt.figure(figsize=(8,5))

plt.scatter(X, y, label='Actual Sales')
plt.plot(X, predictions, label='Prediction Line')

plt.xlabel("Month")
plt.ylabel("Sales")
plt.title("Sales Forecast Prediction")

plt.legend()

plt.show()
